# %% [markdown]
# # Figure 7b - Precipitation Difference Spring Event

# %% [markdown]
# ## 1 - Import Necessary Modules

# %%
import cartopy 
import cartopy.io.shapereader as shpreader 
import cartopy.io.shapereader as Reader 
import matplotlib.pyplot as plt 
import numpy as np 
import proplot as plot
import proplot
import xarray as xr 

from cartopy.feature import ShapelyFeature 
from mpl_toolkits.axes_grid1.inset_locator import inset_axes 
from netCDF4 import Dataset 
from wrf import xy_to_ll 

# warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2 - Functions to Open Datasets and Select Relevant Variables

# %%
def open_wrf_with_variable(member_list, start, end, run_type,daily_sum_or_average = False,):
    """ ÖZET:
    Buradaki olay şu: tüm ensemble memberlarının yağış verilerini salem ile açıyoruz, daha sonra istenilen zaman aralığına kısıyoruz bu veriyi,
    daha sonra bu modifiye edilmiş ensemble verilerini bir listede biriktirip concat ediyoruz ens boyutu üzerinde, daha sonra bu veri'nin ensemble ortalamasını
    alıyoruz, daha sonra ensemble ortalamasını kullanıcıya saatlik olarak mı döneceğiz yoksa zaman aralığı toplamı mı olarak döneceğiz buna karar veriyoruz.
    
        PARAMETERS:
    member_list: ensemble member adlarının listesi (veriyi açmak için),
    start, end: start ve end olarak datetime object yaratıp verilmeli,
    run_type: urban veya nourban stringleri geçirilmeli (hangi veriyi açacağız?),
    daily_sum_or_average: günlük toplam verisini mi çekeceğiz?
                            True ise evet, False ise saatlik veri çeker.
    
        RETURNS:
    Tüm ensemble verilerini yağış için concat eder "ens" boyutu üzerinde ve ens ortalamasını döner. (saatsel ya da günsel olarak)
    
    """
    ## ----------------------------------------------------- ## ADIM 1
    
    # start ve end vakitlerini numpy dt64'e çevirelim
    dt64_start = np.datetime64(start)
    dt64_end = np.datetime64(end)
    
    ## ----------------------------------------------------- ## ADIM 2
    # içinde saatlik wrf verilerini biriktireceğimiz liste
    time_sliced_ensemble = []
    for ens in member_list:
        # hangi ensemble üyesinde olduğumuzu belirtelim
        print("{} ensemble'ı çözülüyor..".format(ens))
        
        ALL = salem.open_wrf_dataset(r"\spring_datasets\ankara_{}_{}\wrfout_d03_2014-05-04_00_00_00".format(ens, run_type))


        
        ## ----------------------------------------------------- ## ŞİMDİLİK ÖNEMSİZ ADIM BAŞLANGIÇ
        # dt64 start ve endi kullanarak np.where komutu ile indexlerini bulalım zamanların ve isel komutu ile bu indexleri kullanalım.
        # aşağıdaki kodu xr open dataset ile açarsak kullanabiliriz.
        #time_sliced_data = ALL['PRCP'].isel(time = slice(np.where(tt['time'] == dt64_start)[0][0], np.where(tt['XTIME'] == dt64_end)[0][0] + 1))
        ## ----------------------------------------------------- ## ŞİMDİLİK ÖNEMSİZ ADIM BİTİŞ
        
        # salem ile açılan veri için saat aralığını seçelim
        time_sliced_data = ALL['PRCP'].sel(time = slice(dt64_start, dt64_end))
        
        # zaman aralıklı verileri bir listede toplayalım
        time_sliced_ensemble.append(time_sliced_data)
        
        # veriyi kapatalım
        ALL.close()
        
    ## ----------------------------------------------------- ## ADIM 3
    
    # saatlik verilerimizi concat edelim ens boyutu üzerinde
    ensemble_runs = xr.concat(time_sliced_ensemble, dim='ens')
    ensemble_runs['ens'] = member_list
    
    ensemble_mean = ensemble_runs.mean(dim='ens') 
    
    ## ----------------------------------------------------- ## ADIM 4
    
    # Artık veriyi saatlik mi dönelim yoksa zaman aralığındaki toplam olarak mı dönelim ona bakıyoruz.
    # saat dilimi toplamı ise:
    if daily_sum_or_average == True:
        ens_time_slice_total = ensemble_mean.sum(dim='time')
        return ens_time_slice_total
    
    # saatlik veri ise:
    elif daily_sum_or_average == False:
        return ensemble_mean
    
    ## ----------------------------------------------------- ## SON

# %%
# AÇIKLAMALARDA REFLEKTİVİTE YERİNE wind OLDUĞUNU VARSAY
def open_wrf_with_wind(member_list, start, end, run_type, var):
    """ ÖZET:
    Buradaki olay şu: tüm ensemble memberlarının yağış verilerini salem ile açıyoruz, daha sonra istenilen zaman aralığına kısıyoruz bu veriyi,
    daha sonra bu modifiye edilmiş ensemble verilerini bir listede biriktirip concat ediyoruz ens boyutu üzerinde, daha sonra bu veri'nin ensemble ortalamasını
    alıyoruz, daha sonra ensemble ortalamasını kullanıcıya saatlik olarak mı döneceğiz yoksa zaman aralığı toplamı mı olarak döneceğiz buna karar veriyoruz.
    
        PARAMETERS:
    member_list: ensemble member adlarının listesi (veriyi açmak için),
    start, end: start ve end olarak time indexleri yaratıp verilmeli,
    run_type: urban veya nourban stringleri geçirilmeli (hangi veriyi açacağız?),
    
        RETURNS:
    Tüm ensemble verilerini dbz için concat eder "ens" boyutu üzerinde döner. 
    
    """
    ## ----------------------------------------------------- ## ADIM 1
    # içinde saatlik wrf verilerini biriktireceğimiz liste
    time_sliced_ensemble = []
    for ens in member_list:
        # hangi ensemble üyesinde olduğumuzu belirtelim
        print("{} ensemble'ı çözülüyor..".format(ens))
        
        ALL = Dataset(r'\spring_datasets\ankara_{}_{}\wrfout_d03_2014-05-04_00_00_00'.format(ens, run_type))
        
        dbzs_with_time = []
        # burada time dimensionu üzerinde dönüp tüm dbz leri time boyutunda concat edeceğim
        # maalesef getvar özelliği sadece tek bir zaman dilimini açmakta..
        for t in range(start, end):
            # max reflectivity açalım tek bir zaman dilimi için
            
            dbz = getvar(ALL, var, timeidx=t, units = 'kt')        
            # bu zaman dilimini bir listeye atayalım ve dolduralım
            dbzs_with_time.append(dbz)
            
            print('{}: {}/{} zaman adımı bitti'.format(ens, t, end))
        
        # tek bir ensembleın tüm zamanlarının olduğu max reflectivity değişkenlerini concat edelim ve ensemble listesine atayalım
        tempor_concat = xr.concat(dbzs_with_time, dim='Time')
        time_sliced_ensemble.append(tempor_concat)
        
        
        # veriyi kapatalım
        ALL.close()
        
    ## ----------------------------------------------------- ## ADIM 2
    
    # saatlik verilerimizi concat edelim ens boyutu üzerinde
    ensemble_runs = xr.concat(time_sliced_ensemble, dim='ens')
    ensemble_runs['ens'] = member_list
    
    return ensemble_runs.mean(dim='ens')

# %% [markdown]
# ## 3 - Open Datasets

# %%
# URBAN data
member_list = ['lin', 'thompson', 'wsm6']
start = datetime(2014, 5, 5, 0)
end = datetime(2014, 5, 5, 23)
run_type = 'urban'

urban_ens_mean_daily_total = open_wrf_with_variable(member_list, start, end, run_type, True)
urban_ens_mean_hourly = open_wrf_with_variable(member_list, start, end, run_type, False)

print('done with urban....')
## ------------------------------------------------------------------------------------------------- ##
# NOURBAN VERİLERİNİ AÇALIM
start = datetime(2014, 5, 5, 0)
end = datetime(2014, 5, 5, 23)
run_type = 'nourban'

nourban_ens_mean_daily_total = open_wrf_with_variable(member_list, start, end, run_type, True)
nourban_ens_mean_hourly = open_wrf_with_variable(member_list, start, end, run_type, False)

print('done with nourban....')
# Out:
# lin ensemble'ı çözülüyor..
# thompson ensemble'ı çözülüyor..
# wsm6 ensemble'ı çözülüyor..
# lin ensemble'ı çözülüyor..
# thompson ensemble'ı çözülüyor..
# wsm6 ensemble'ı çözülüyor..
# done with urban....
# lin ensemble'ı çözülüyor..
# thompson ensemble'ı çözülüyor..
# wsm6 ensemble'ı çözülüyor..
# lin ensemble'ı çözülüyor..
# thompson ensemble'ı çözülüyor..
# wsm6 ensemble'ı çözülüyor..
# done with nourban....

# %%
#precipitation
urban_minus_nourban_daily_total = urban_ens_mean_daily_total - nourban_ens_mean_daily_total
urban_minus_nourban_hourly = urban_ens_mean_hourly - nourban_ens_mean_hourly

# %% [markdown]
# ##### Wind Data

# %%
start_index = 29
end_index = 41
# -------------------------------URBAN ---------------------------------------------------
run_type = 'urban'

ua_urban_ens_mean_wind = open_wrf_with_wind(member_list, start_index, end_index, run_type, var = 'ua')
va_urban_ens_mean_wind = open_wrf_with_wind(member_list, start_index, end_index, run_type, var = 'va')
ua_va_urban = xr.merge([ua_urban_ens_mean_wind, va_urban_ens_mean_wind])

print('URBAN İS DONE')

# -------------------------------NOURBAN ---------------------------------------------------

run_type = 'nourban'

ua_nourban_ens_mean_wind = open_wrf_with_wind(member_list, start_index, end_index, run_type, var = 'ua')
va_nourban_ens_mean_wind = open_wrf_with_wind(member_list, start_index, end_index, run_type, var = 'va')
ua_va_nourban = xr.merge([ua_nourban_ens_mean_wind, va_nourban_ens_mean_wind])

print('NOURBAN İS DONE')
# Out:
# lin ensemble'ı çözülüyor..
# lin: 29/41 zaman adımı bitti
# lin: 30/41 zaman adımı bitti
# lin: 31/41 zaman adımı bitti
# lin: 32/41 zaman adımı bitti
# lin: 33/41 zaman adımı bitti
# lin: 34/41 zaman adımı bitti
# lin: 35/41 zaman adımı bitti
# lin: 36/41 zaman adımı bitti
# lin: 37/41 zaman adımı bitti
# lin: 38/41 zaman adımı bitti
# lin: 39/41 zaman adımı bitti
# lin: 40/41 zaman adımı bitti
# thompson ensemble'ı çözülüyor..
# thompson: 29/41 zaman adımı bitti
# thompson: 30/41 zaman adımı bitti
# thompson: 31/41 zaman adımı bitti
# thompson: 32/41 zaman adımı bitti
# thompson: 33/41 zaman adımı bitti
# thompson: 34/41 zaman adımı bitti
# thompson: 35/41 zaman adımı bitti
# thompson: 36/41 zaman adımı bitti
# thompson: 37/41 zaman adımı bitti
# thompson: 38/41 zaman adımı bitti
# thompson: 39/41 zaman adımı bitti
# thompson: 40/41 zaman adımı bitti
# wsm6 ensemble'ı çözülüyor..
# wsm6: 29/41 zaman adımı bitti
# wsm6: 30/41 zaman adımı bitti
# wsm6: 31/41 zaman adımı bitti
# wsm6: 32/41 zaman adımı bitti
# wsm6: 33/41 zaman adımı bitti
# wsm6: 34/41 zaman adımı bitti
# wsm6: 35/41 zaman adımı bitti
# wsm6: 36/41 zaman adımı bitti
# wsm6: 37/41 zaman adımı bitti
# wsm6: 38/41 zaman adımı bitti
# wsm6: 39/41 zaman adımı bitti
# wsm6: 40/41 zaman adımı bitti
# lin ensemble'ı çözülüyor..
# lin: 29/41 zaman adımı bitti
# lin: 30/41 zaman adımı bitti
# lin: 31/41 zaman adımı bitti
# lin: 32/41 zaman adımı bitti
# lin: 33/41 zaman adımı bitti
# lin: 34/41 zaman adımı bitti
# lin: 35/41 zaman adımı bitti
# lin: 36/41 zaman adımı bitti
# lin: 37/41 zaman adımı bitti
# lin: 38/41 zaman adımı bitti
# lin: 39/41 zaman adımı bitti
# lin: 40/41 zaman adımı bitti
# thompson ensemble'ı çözülüyor..
# thompson: 29/41 zaman adımı bitti
# thompson: 30/41 zaman adımı bitti
# thompson: 31/41 zaman adımı bitti
# thompson: 32/41 zaman adımı bitti
# thompson: 33/41 zaman adımı bitti
# thompson: 34/41 zaman adımı bitti
# thompson: 35/41 zaman adımı bitti
# thompson: 36/41 zaman adımı bitti
# thompson: 37/41 zaman adımı bitti
# thompson: 38/41 zaman adımı bitti
# thompson: 39/41 zaman adımı bitti
# thompson: 40/41 zaman adımı bitti
# wsm6 ensemble'ı çözülüyor..
# wsm6: 29/41 zaman adımı bitti
# wsm6: 30/41 zaman adımı bitti
# wsm6: 31/41 zaman adımı bitti
# wsm6: 32/41 zaman adımı bitti
# wsm6: 33/41 zaman adımı bitti
# wsm6: 34/41 zaman adımı bitti
# wsm6: 35/41 zaman adımı bitti
# wsm6: 36/41 zaman adımı bitti
# wsm6: 37/41 zaman adımı bitti
# wsm6: 38/41 zaman adımı bitti
# wsm6: 39/41 zaman adımı bitti
# wsm6: 40/41 zaman adımı bitti
# URBAN İS DONE
# lin ensemble'ı çözülüyor..
# lin: 29/41 zaman adımı bitti
# lin: 30/41 zaman adımı bitti
# lin: 31/41 zaman adımı bitti
# lin: 32/41 zaman adımı bitti
# lin: 33/41 zaman adımı bitti
# lin: 34/41 zaman adımı bitti
# lin: 35/41 zaman adımı bitti
# lin: 36/41 zaman adımı bitti
# lin: 37/41 zaman adımı bitti
# lin: 38/41 zaman adımı bitti
# lin: 39/41 zaman adımı bitti
# lin: 40/41 zaman adımı bitti
# thompson ensemble'ı çözülüyor..
# thompson: 29/41 zaman adımı bitti
# thompson: 30/41 zaman adımı bitti
# thompson: 31/41 zaman adımı bitti
# thompson: 32/41 zaman adımı bitti
# thompson: 33/41 zaman adımı bitti
# thompson: 34/41 zaman adımı bitti
# thompson: 35/41 zaman adımı bitti
# thompson: 36/41 zaman adımı bitti
# thompson: 37/41 zaman adımı bitti
# thompson: 38/41 zaman adımı bitti
# thompson: 39/41 zaman adımı bitti
# thompson: 40/41 zaman adımı bitti
# wsm6 ensemble'ı çözülüyor..
# wsm6: 29/41 zaman adımı bitti
# wsm6: 30/41 zaman adımı bitti
# wsm6: 31/41 zaman adımı bitti
# wsm6: 32/41 zaman adımı bitti
# wsm6: 33/41 zaman adımı bitti
# wsm6: 34/41 zaman adımı bitti
# wsm6: 35/41 zaman adımı bitti
# wsm6: 36/41 zaman adımı bitti
# wsm6: 37/41 zaman adımı bitti
# wsm6: 38/41 zaman adımı bitti
# wsm6: 39/41 zaman adımı bitti
# wsm6: 40/41 zaman adımı bitti
# lin ensemble'ı çözülüyor..
# lin: 29/41 zaman adımı bitti
# lin: 30/41 zaman adımı bitti
# lin: 31/41 zaman adımı bitti
# lin: 32/41 zaman adımı bitti
# lin: 33/41 zaman adımı bitti
# lin: 34/41 zaman adımı bitti
# lin: 35/41 zaman adımı bitti
# lin: 36/41 zaman adımı bitti
# lin: 37/41 zaman adımı bitti
# lin: 38/41 zaman adımı bitti
# lin: 39/41 zaman adımı bitti
# lin: 40/41 zaman adımı bitti
# thompson ensemble'ı çözülüyor..
# thompson: 29/41 zaman adımı bitti
# thompson: 30/41 zaman adımı bitti
# thompson: 31/41 zaman adımı bitti
# thompson: 32/41 zaman adımı bitti
# thompson: 33/41 zaman adımı bitti
# thompson: 34/41 zaman adımı bitti
# thompson: 35/41 zaman adımı bitti
# thompson: 36/41 zaman adımı bitti
# thompson: 37/41 zaman adımı bitti
# thompson: 38/41 zaman adımı bitti
# thompson: 39/41 zaman adımı bitti
# thompson: 40/41 zaman adımı bitti
# wsm6 ensemble'ı çözülüyor..
# wsm6: 29/41 zaman adımı bitti
# wsm6: 30/41 zaman adımı bitti
# wsm6: 31/41 zaman adımı bitti
# wsm6: 32/41 zaman adımı bitti
# wsm6: 33/41 zaman adımı bitti
# wsm6: 34/41 zaman adımı bitti
# wsm6: 35/41 zaman adımı bitti
# wsm6: 36/41 zaman adımı bitti
# wsm6: 37/41 zaman adımı bitti
# wsm6: 38/41 zaman adımı bitti
# wsm6: 39/41 zaman adımı bitti
# wsm6: 40/41 zaman adımı bitti
# NOURBAN İS DONE

# %%
# rüzgarlar için pressure level belirleyecez, örnek veri açalım p variablei için
ALL = Dataset(r'\spring_datasets\ankara_{}_{}\wrfout_d03_2014-05-04_00_00_00'.format('lin', 'urban'))
p = getvar(ALL, "pressure")

# urban 1000
ua_urban_850_500 = interplevel(ua_va_urban['ua'], p, [850, 500])
va_urban_850_500 = interplevel(ua_va_urban['va'], p, [850, 500])

# nourban 1000
ua_nourban_850_500 = interplevel(ua_va_nourban['ua'], p, [850, 500])
va_nourban_850_500 = interplevel(ua_va_nourban['va'], p, [850, 500])

# %%
# ek plot bilgileri;
#open example data for getting the borders of city
d_urban = Dataset(r'\spring_datasets\ankara_thompson_urban\wrfout_d03_2014-05-04_00_00_00')

d_sol_alt3 = xy_to_ll(d_urban, 0, 0).values
d_sol_ust3 = xy_to_ll(d_urban, 0, 200).values
d_sag_alt3 = xy_to_ll(d_urban, 200, 0).values
d_sag_ust3 = xy_to_ll(d_urban, 200, 200).values

lon_wrf = urban_ens_mean_daily_total['lon']
lat_wrf = urban_ens_mean_daily_total['lat']

# %% [markdown]
# ## 4 - Corner Coordinates

# %%
#Define urban and rural box coordinates - 
urban_sol_alt_coordinates = [32.63, 39.85]
urban_sol_ust_coordinates = [32.63, 40.01]
urban_sag_alt_coordinates = [32.89, 39.85]
urban_sag_ust_coordinates = [32.89, 40.01]


upwind_sol_alt_coordinates = [32.33, 39.93]
upwind_sol_ust_coordinates = [32.33, 40.09]
upwind_sag_alt_coordinates = [32.59, 39.93]
upwind_sag_ust_coordinates = [32.59, 40.09]

downwind_sol_alt_coordinates = [32.93, 39.77]
downwind_sol_ust_coordinates = [32.93, 39.93]
downwind_sag_alt_coordinates = [33.19, 39.77]
downwind_sag_ust_coordinates = [33.19, 39.93]

# %% [markdown]
# ## 5 - Create Plots

# %%
cmap_diff_total = plot.Colormap('Brown1_r', 'white', 'Green5',
    ratios=(12/30, 6/30, 12/30), 
    name='SciVisColor', save=True)

# %%
#Starting the plotting
cart_proj = cartopy.crs.LambertConformal( 32.834, 39.873 )
fig, axs = plot.subplots(ncols=1, nrows=1, proj=cart_proj)

#format the plot
axs.format(
    lonlim=(d_sol_alt3[1], d_sag_alt3[1]-0.10),
    latlim=(d_sol_alt3[0], d_sol_ust3[0]-0.10),
    coast = True, labels=False, innerborders=True,
    reso = 'xx-hi', coastlinewidth = 2, innerborderslinewidth = 1,
    land = True, landcolor = '#f0e7d8', landzorder = 0.005,
    borderszorder = 3, innerborderszorder = 3, 
    abc=False, abcstyle='(a)', abcloc='ur')

#urban box
axs.plot([urban_sol_alt_coordinates[0], urban_sol_ust_coordinates[0]], 
         [urban_sol_alt_coordinates[1], urban_sol_ust_coordinates[1]], 
         transform=cartopy.crs.PlateCarree(), color='black', linewidth=2)
axs.plot([urban_sol_ust_coordinates[0], urban_sag_ust_coordinates[0]], 
         [urban_sol_ust_coordinates[1], urban_sag_ust_coordinates[1]], 
         transform=cartopy.crs.PlateCarree(), color='black', linewidth=2)
axs.plot([urban_sag_ust_coordinates[0], urban_sag_alt_coordinates[0]], 
         [urban_sag_ust_coordinates[1], urban_sag_alt_coordinates[1]], 
         transform=cartopy.crs.PlateCarree(), color='black', linewidth=2)
axs.plot([urban_sol_alt_coordinates[0], urban_sag_alt_coordinates[0]], 
         [urban_sol_alt_coordinates[1], urban_sag_alt_coordinates[1]], 
         transform=cartopy.crs.PlateCarree(), color='black', linewidth=2)

#upwind box
axs.plot([upwind_sol_alt_coordinates[0], upwind_sol_ust_coordinates[0]], 
         [upwind_sol_alt_coordinates[1], upwind_sol_ust_coordinates[1]], 
         transform=cartopy.crs.PlateCarree(), color='red', linewidth=2)
axs.plot([upwind_sol_ust_coordinates[0], upwind_sag_ust_coordinates[0]], 
         [upwind_sol_ust_coordinates[1], upwind_sag_ust_coordinates[1]], 
         transform=cartopy.crs.PlateCarree(), color='red', linewidth=2)
axs.plot([upwind_sag_ust_coordinates[0], upwind_sag_alt_coordinates[0]], 
         [upwind_sag_ust_coordinates[1], upwind_sag_alt_coordinates[1]], 
         transform=cartopy.crs.PlateCarree(), color='red', linewidth=2)
axs.plot([upwind_sol_alt_coordinates[0], upwind_sag_alt_coordinates[0]], 
         [upwind_sol_alt_coordinates[1], upwind_sag_alt_coordinates[1]], 
         transform=cartopy.crs.PlateCarree(), color='red', linewidth=2)

#downwind box
axs.plot([downwind_sol_alt_coordinates[0], downwind_sol_ust_coordinates[0]], 
         [downwind_sol_alt_coordinates[1], downwind_sol_ust_coordinates[1]], 
         transform=cartopy.crs.PlateCarree(), color='blue', linewidth=2)
axs.plot([downwind_sol_ust_coordinates[0], downwind_sag_ust_coordinates[0]], 
         [downwind_sol_ust_coordinates[1], downwind_sag_ust_coordinates[1]], 
         transform=cartopy.crs.PlateCarree(), color='blue', linewidth=2)
axs.plot([downwind_sag_ust_coordinates[0], downwind_sag_alt_coordinates[0]], 
         [downwind_sag_ust_coordinates[1], downwind_sag_alt_coordinates[1]], 
         transform=cartopy.crs.PlateCarree(), color='blue', linewidth=2)
axs.plot([downwind_sol_alt_coordinates[0], downwind_sag_alt_coordinates[0]], 
         [downwind_sol_alt_coordinates[1], downwind_sag_alt_coordinates[1]], 
         transform=cartopy.crs.PlateCarree(), color='blue', linewidth=2)


## -----------------------------------------URBAN-NOURBAN-------------------------------------------------------- ##

# URBAN-NOURBAN ensemble mean için plot
run_plot_diff = axs[0].pcolormesh(lon_wrf, lat_wrf,
                                  urban_minus_nourban_daily_total,
                                  levels = np.arange(-15, 16, 3),
                                  cmap=cmap_diff_total, extend='both', 
                                  transform=cartopy.crs.PlateCarree(), zorder = 0.01)

axs[0].format(ultitle = 'URBAN-NOURBAN', fontsize = 10)
cbar = fig.colorbar(run_plot_diff, label='mm',
                    labelweight='bold', 
                    ticks = np.arange(-15, 16, 3),
                    loc = 'b', col=1, ) #Adding colorbar with label

cbar.ax.set_xticklabels(labels = np.arange(-15, 16, 3),
                        rotation=290)

#save figure
plt.savefig(r'pictures\figure7a.jpeg',
            bbox_inches='tight', optimize=True,
            progressive=True, dpi=500)
# Out:
# C:\Users\User\anaconda3\envs\berkay\lib\site-packages\proplot\figure.py:94: MatplotlibDeprecationWarning:
# The 'optimize' parameter of print_jpg() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use pil_kwargs={'optimize': ...} instead. If any parameter follows 'optimize', they should be passed as keyword, not positionally.
#   result = func(self, *args, **kwargs)
# C:\Users\User\anaconda3\envs\berkay\lib\site-packages\proplot\figure.py:94: MatplotlibDeprecationWarning:
# The 'progressive' parameter of print_jpg() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use pil_kwargs={'progressive': ...} instead. If any parameter follows 'progressive', they should be passed as keyword, not positionally.
#   result = func(self, *args, **kwargs)
